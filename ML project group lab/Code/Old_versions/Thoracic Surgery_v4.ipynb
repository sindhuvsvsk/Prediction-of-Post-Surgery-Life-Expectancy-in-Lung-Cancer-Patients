# %% [markdown]
# ### Loading the dataset

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from collections import Counter
import matplotlib.gridspec as gridspec

# %%
surgery = pd.read_csv("ThoraricSurgery.csv")

# %%
surgery.head()
# Out:
#    id   DGN  PRE4  PRE5  PRE6 PRE7 PRE8 PRE9 PRE10 PRE11 PRE14 PRE17 PRE19  \
# 0   1  DGN2  2.88  2.16  PRZ1    F    F    F     T     T  OC14     F     F
# 1   2  DGN3  3.40  1.88  PRZ0    F    F    F     F     F  OC12     F     F
# 2   3  DGN3  2.76  2.08  PRZ1    F    F    F     T     F  OC11     F     F
# 3   4  DGN3  3.68  3.04  PRZ0    F    F    F     F     F  OC11     F     F
# 4   5  DGN3  2.44  0.96  PRZ2    F    T    F     T     T  OC11     F     F
#
#   PRE25 PRE30 PRE32  AGE Risk1Yr
# 0     F     T     F   60       F
# 1     F     T     F   51       F
# 2     F     T     F   59       F
# 3     F     F     F   54       F
# 4     F     T     F   73       T

# %%
surgery.tail()
# Out:
#       id   DGN  PRE4  PRE5  PRE6 PRE7 PRE8 PRE9 PRE10 PRE11 PRE14 PRE17 PRE19  \
# 465  466  DGN2  3.88  2.12  PRZ1    F    F    F     T     F  OC13     F     F
# 466  467  DGN3  3.76  3.12  PRZ0    F    F    F     F     F  OC11     F     F
# 467  468  DGN3  3.04  2.08  PRZ1    F    F    F     T     F  OC13     F     F
# 468  469  DGN3  1.96  1.68  PRZ1    F    F    F     T     T  OC12     F     F
# 469  470  DGN3  4.72  3.56  PRZ0    F    F    F     F     F  OC12     F     F
#
#     PRE25 PRE30 PRE32  AGE Risk1Yr
# 465     F     T     F   63       F
# 466     F     T     F   61       F
# 467     F     F     F   52       F
# 468     F     T     F   79       F
# 469     F     T     F   51       F

# %% [markdown]
# #### To remove warnings

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Descriptive statistics

# %%
surgery.describe()
# Out:
#                id        PRE4        PRE5         AGE
# count  470.000000  470.000000  470.000000  470.000000
# mean   235.500000    3.281638    4.568702   62.534043
# std    135.821574    0.871395   11.767857    8.706902
# min      1.000000    1.440000    0.960000   21.000000
# 25%    118.250000    2.600000    1.960000   57.000000
# 50%    235.500000    3.160000    2.400000   62.000000
# 75%    352.750000    3.807500    3.080000   69.000000
# max    470.000000    6.300000   86.300000   87.000000

# %% [markdown]
# ### Number of rows and columns

# %%
surgery.shape
# Out:
# (470, 18)

# %%
duplicate_rows = surgery[surgery.duplicated()]
print("number of duplicate rows: ", duplicate_rows.shape)
# Out:
# number of duplicate rows:  (0, 18)

# %% [markdown]
# ### Understanding the data set

# %% [markdown]
# #### Description of the features in the dataset.

# %%
description = pd.read_excel('Thoracic surgery-description.xlsx').dropna()
description.style.set_properties(subset=['Description'])
# Out:
# <style  type="text/css" >
# </style><table id="T_45fc63ee_258a_11eb_a737_a0cec83716d8" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Attributes</th>        <th class="col_heading level0 col1" >Description</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_45fc63ee_258a_11eb_a737_a0cec83716d8level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_45fc63ee_258a_11eb_a737_a0cec83716d8row0_col0" class="data row0 col0" >DGN</td>
#                         <td id="T_45fc63ee_258a_11eb_a737_a0cec83716d8row0_col1" class="data row0 col1" >Diagnosis - specific combination of ICD-10 codes for primary and secondary as well multiple tumours if any (DGN3,DGN2,DGN4,DGN6,DGN5,DGN8,DGN1)</td>
#             </tr>
#             <tr>
#                         <th id="T_45fc63ee_258a_11eb_a737_a0cec83716d8level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_45fc63ee_258a_11eb_a737_a0cec83716d8row1_col0" class="data row1 col0" >PRE4</td>
#                         <td id="T_45fc63ee_258a_11eb_a737_a0cec83716d8row1_col1" class="data row1 col1" >Forced Vital Capacity - FVC (numeric)</td>
#             </tr>
#             <tr>
#                         <th id="T_45fc63ee_258a_11eb_a737_a0cec83716d8level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_45fc63ee_258a_11eb_a737_a0cec83716d8row2_col0" class="data row2 col0" >PRE5</td>
#                         <td id="T_45fc63ee_258a_11eb_a737_a0cec83716d8row2_col1" class="data row2 col1" >Volume that has been exhaled at the end of the first second of forced expiration - FEV1 (numeric)</td>
#             </tr>
#             <tr>
#                         <th id="T_45fc63ee_258a_11eb_a737_a0cec83716d8level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_45fc63ee_258a_11eb_a737_a0cec83716d8row3_col0" class="data row3 col0" >PRE6</td>
#                         <td id="T_45fc63ee_258a_11eb_a737_a0cec83716d8row3_col1" class="data row3 col1" >Performance status - Zubrod scale (PRZ2,PRZ1,PRZ0)</td>
#             </tr>
#             <tr>
#                         <th id="T_45fc63ee_258a_11eb_a737_a0cec83716d8level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_45fc63ee_258a_11eb_a737_a0cec83716d8row4_col0" class="data row4 col0" >PRE7</td>
#                         <td id="T_45fc63ee_258a_11eb_a737_a0cec83716d8row4_col1" class="data row4 col1" >Pain before surgery (T,F)</td>
#             </tr>
#             <tr>
#                         <th id="T_45fc63ee_258a_11eb_a737_a0cec83716d8level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_45fc63ee_258a_11eb_a737_a0cec83716d8row5_col0" class="data row5 col0" >PRE8</td>
#                         <td id="T_45fc63ee_258a_11eb_a737_a0cec83716d8row5_col1" class="data row5 col1" >Haemoptysis before surgery (T,F)</td>
#             </tr>
#             <tr>
#                         <th id="T_45fc63ee_258a_11eb_a737_a0cec83716d8level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_45fc63ee_258a_11eb_a737_a0cec83716d8row6_col0" class="data row6 col0" >PRE9</td>
#                         <td id="T_45fc63ee_258a_11eb_a737_a0cec83716d8row6_col1" class="data row6 col1" >Dyspnoea before surgery (T,F)</td>
#             </tr>
#             <tr>
#                         <th id="T_45fc63ee_258a_11eb_a737_a0cec83716d8level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_45fc63ee_258a_11eb_a737_a0cec83716d8row7_col0" class="data row7 col0" >PRE10</td>
#                         <td id="T_45fc63ee_258a_11eb_a737_a0cec83716d8row7_col1" class="data row7 col1" >Cough before surgery (T,F)</td>
#             </tr>
#             <tr>
#                         <th id="T_45fc63ee_258a_11eb_a737_a0cec83716d8level0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_45fc63ee_258a_11eb_a737_a0cec83716d8row8_col0" class="data row8 col0" >PRE11</td>
#                         <td id="T_45fc63ee_258a_11eb_a737_a0cec83716d8row8_col1" class="data row8 col1" >Weakness before surgery (T,F)</td>
#             </tr>
#             <tr>
#                         <th id="T_45fc63ee_258a_11eb_a737_a0cec83716d8level0_row9" class="row_heading level0 row9" >9</th>
#                         <td id="T_45fc63ee_258a_11eb_a737_a0cec83716d8row9_col0" class="data row9 col0" >PRE14</td>
#                         <td id="T_45fc63ee_258a_11eb_a737_a0cec83716d8row9_col1" class="data row9 col1" >T in clinical TNM - size of the original tumour, from OC11 (smallest) to OC14 (largest) (OC11,OC14,OC12,OC13)</td>
#             </tr>
#             <tr>
#                         <th id="T_45fc63ee_258a_11eb_a737_a0cec83716d8level0_row10" class="row_heading level0 row10" >10</th>
#                         <td id="T_45fc63ee_258a_11eb_a737_a0cec83716d8row10_col0" class="data row10 col0" >PRE17</td>
#                         <td id="T_45fc63ee_258a_11eb_a737_a0cec83716d8row10_col1" class="data row10 col1" >Type 2 DM - diabetes mellitus (T,F)</td>
#             </tr>
#             <tr>
#                         <th id="T_45fc63ee_258a_11eb_a737_a0cec83716d8level0_row11" class="row_heading level0 row11" >11</th>
#                         <td id="T_45fc63ee_258a_11eb_a737_a0cec83716d8row11_col0" class="data row11 col0" >PRE19</td>
#                         <td id="T_45fc63ee_258a_11eb_a737_a0cec83716d8row11_col1" class="data row11 col1" >MI up to 6 months (T,F)</td>
#             </tr>
#             <tr>
#                         <th id="T_45fc63ee_258a_11eb_a737_a0cec83716d8level0_row12" class="row_heading level0 row12" >12</th>
#                         <td id="T_45fc63ee_258a_11eb_a737_a0cec83716d8row12_col0" class="data row12 col0" >PRE25</td>
#                         <td id="T_45fc63ee_258a_11eb_a737_a0cec83716d8row12_col1" class="data row12 col1" >PAD - Peripheral Arterial Diseases (T,F)</td>
#             </tr>
#             <tr>
#                         <th id="T_45fc63ee_258a_11eb_a737_a0cec83716d8level0_row13" class="row_heading level0 row13" >13</th>
#                         <td id="T_45fc63ee_258a_11eb_a737_a0cec83716d8row13_col0" class="data row13 col0" >PRE30</td>
#                         <td id="T_45fc63ee_258a_11eb_a737_a0cec83716d8row13_col1" class="data row13 col1" >Smoking (T,F)</td>
#             </tr>
#             <tr>
#                         <th id="T_45fc63ee_258a_11eb_a737_a0cec83716d8level0_row14" class="row_heading level0 row14" >14</th>
#                         <td id="T_45fc63ee_258a_11eb_a737_a0cec83716d8row14_col0" class="data row14 col0" >PRE32</td>
#                         <td id="T_45fc63ee_258a_11eb_a737_a0cec83716d8row14_col1" class="data row14 col1" >Asthma (T,F)</td>
#             </tr>
#             <tr>
#                         <th id="T_45fc63ee_258a_11eb_a737_a0cec83716d8level0_row15" class="row_heading level0 row15" >15</th>
#                         <td id="T_45fc63ee_258a_11eb_a737_a0cec83716d8row15_col0" class="data row15 col0" >AGE</td>
#                         <td id="T_45fc63ee_258a_11eb_a737_a0cec83716d8row15_col1" class="data row15 col1" >Age at the time of surgery (numeric)</td>
#             </tr>
#             <tr>
#                         <th id="T_45fc63ee_258a_11eb_a737_a0cec83716d8level0_row16" class="row_heading level0 row16" >16</th>
#                         <td id="T_45fc63ee_258a_11eb_a737_a0cec83716d8row16_col0" class="data row16 col0" >Risk1Y</td>
#                         <td id="T_45fc63ee_258a_11eb_a737_a0cec83716d8row16_col1" class="data row16 col1" >1 year survival period - (T)rue value if died (T,F)</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# ### Renaming the attributes of the dataset

# %%
col = ['ID','Diagnosis','Forced_Capacity','Forced_Expiration','Zubrod_scale','Pain','Haemoptysis','Dyspnoea',
       'Cough','Weakness','Size_of_tumor','Diabetes','MI_6months','PAD','Smoker','Asthmatic','Age','Risk_1year']
surgery.columns = col

# %%
surgery.head()
# Out:
#    ID Diagnosis  Forced_Capacity  Forced_Expiration Zubrod_scale Pain  \
# 0   1      DGN2             2.88               2.16         PRZ1    F
# 1   2      DGN3             3.40               1.88         PRZ0    F
# 2   3      DGN3             2.76               2.08         PRZ1    F
# 3   4      DGN3             3.68               3.04         PRZ0    F
# 4   5      DGN3             2.44               0.96         PRZ2    F
#
#   Haemoptysis Dyspnoea Cough Weakness Size_of_tumor Diabetes MI_6months PAD  \
# 0           F        F     T        T          OC14        F          F   F
# 1           F        F     F        F          OC12        F          F   F
# 2           F        F     T        F          OC11        F          F   F
# 3           F        F     F        F          OC11        F          F   F
# 4           T        F     T        T          OC11        F          F   F
#
#   Smoker Asthmatic  Age Risk_1year
# 0      T         F   60          F
# 1      T         F   51          F
# 2      T         F   59          F
# 3      F         F   54          F
# 4      T         F   73          T

# %% [markdown]
# ### Missing values

# %% [markdown]
# #### Checking the number of null values and data type of the variables present in the data set

# %%
surgery.isna().sum()
# Out:
# ID                   0
# Diagnosis            0
# Forced_Capacity      0
# Forced_Expiration    0
# Zubrod_scale         0
# Pain                 0
# Haemoptysis          0
# Dyspnoea             0
# Cough                0
# Weakness             0
# Size_of_tumor        0
# Diabetes             0
# MI_6months           0
# PAD                  0
# Smoker               0
# Asthmatic            0
# Age                  0
# Risk_1year           0
# dtype: int64

# %% [markdown]
# #### Calculating the number of missing vallues in each feature of the dataset

# %%
missing = surgery.isnull().sum()
missing_perc = (missing/len(surgery))*100
miss_val_table = pd.concat([missing, missing_perc], axis=1)
miss_val_table_rename_col = miss_val_table.rename(columns = {0 : 'Missing Values', 1 : '% of MissingValues'})
miss_val_table_rename_col = miss_val_table_rename_col[miss_val_table_rename_col.iloc[:,1] != 0].sort_values('% of MissingValues', ascending=False).round(1)
print("Thoracic Surgery dataset has " + str(surgery.shape[1]) + " columns.\nThere are "+ str(miss_val_table_rename_col.shape[0]) + " columns that have missing values.")
# Out:
# Thoracic Surgery dataset has 18 columns.
# There are 0 columns that have missing values.

# %% [markdown]
# #### Changing the values of the categorical variables, to improve the interpretation

# %%
surgery['Diagnosis'][surgery['Diagnosis'] == 'DGN1'] = 'Diagnosis_1'
surgery['Diagnosis'][surgery['Diagnosis'] == 'DGN2'] = 'Diagnosis_2'
surgery['Diagnosis'][surgery['Diagnosis'] == 'DGN3'] = 'Diagnosis_3'
surgery['Diagnosis'][surgery['Diagnosis'] == 'DGN4'] = 'Diagnosis_4'
surgery['Diagnosis'][surgery['Diagnosis'] == 'DGN5'] = 'Diagnosis_5'
surgery['Diagnosis'][surgery['Diagnosis'] == 'DGN6'] = 'Diagnosis_6'
surgery['Diagnosis'][surgery['Diagnosis'] == 'DGN8'] = 'Diagnosis_8'

surgery['Zubrod_scale'][surgery['Zubrod_scale'] == 'PRZ0'] = 'Zubrod_scale_0'
surgery['Zubrod_scale'][surgery['Zubrod_scale'] == 'PRZ1'] = 'Zubrod_scale_1'
surgery['Zubrod_scale'][surgery['Zubrod_scale'] == 'PRZ2'] = 'Zubrod_scale_2'

surgery['Pain'][surgery['Pain'] == 'F'] = 'False'
surgery['Pain'][surgery['Pain'] == 'T'] = 'True'

surgery['Haemoptysis'][surgery['Haemoptysis'] == 'F'] = 'False'
surgery['Haemoptysis'][surgery['Haemoptysis'] == 'T'] = 'True'

surgery['Dyspnoea'][surgery['Dyspnoea'] == 'F'] = 'False'
surgery['Dyspnoea'][surgery['Dyspnoea'] == 'T'] = 'True'

surgery['Cough'][surgery['Cough'] == 'F'] = 'False'
surgery['Cough'][surgery['Cough'] == 'T'] = 'True'

surgery['Weakness'][surgery['Weakness'] == 'F'] = 'False'
surgery['Weakness'][surgery['Weakness'] == 'T'] = 'True'

surgery['Diabetes'][surgery['Diabetes'] == 'F'] = 'False'
surgery['Diabetes'][surgery['Diabetes'] == 'T'] = 'True'

surgery['MI_6months'][surgery['MI_6months'] == 'F'] = 'False'
surgery['MI_6months'][surgery['MI_6months'] == 'T'] = 'True'


surgery['PAD'][surgery['PAD'] == 'F'] = 'False'
surgery['PAD'][surgery['PAD'] == 'T'] = 'True'


surgery['Smoker'][surgery['Smoker'] == 'F'] = 'False'
surgery['Smoker'][surgery['Smoker'] == 'T'] = 'True'

surgery['Asthmatic'][surgery['Asthmatic'] == 'F'] = 'False'
surgery['Asthmatic'][surgery['Asthmatic'] == 'T'] = 'True'

surgery['Risk_1year'][surgery['Risk_1year'] == 'F'] = 'False'
surgery['Risk_1year'][surgery['Risk_1year'] == 'T'] = 'True'

# %%
surgery.head()
# Out:
#    ID    Diagnosis  Forced_Capacity  Forced_Expiration    Zubrod_scale   Pain  \
# 0   1  Diagnosis_2             2.88               2.16  Zubrod_scale_1  False
# 1   2  Diagnosis_3             3.40               1.88  Zubrod_scale_0  False
# 2   3  Diagnosis_3             2.76               2.08  Zubrod_scale_1  False
# 3   4  Diagnosis_3             3.68               3.04  Zubrod_scale_0  False
# 4   5  Diagnosis_3             2.44               0.96  Zubrod_scale_2  False
#
#   Haemoptysis Dyspnoea  Cough Weakness Size_of_tumor Diabetes MI_6months  \
# 0       False    False   True     True          OC14    False      False
# 1       False    False  False    False          OC12    False      False
# 2       False    False   True    False          OC11    False      False
# 3       False    False  False    False          OC11    False      False
# 4        True    False   True     True          OC11    False      False
#
#      PAD Smoker Asthmatic  Age Risk_1year
# 0  False   True     False   60      False
# 1  False   True     False   51      False
# 2  False   True     False   59      False
# 3  False  False     False   54      False
# 4  False   True     False   73       True

# %% [markdown]
# ### Displaying  data present in the csv file

# %%
surgery.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 470 entries, 0 to 469
# Data columns (total 18 columns):
# ID                   470 non-null int64
# Diagnosis            470 non-null object
# Forced_Capacity      470 non-null float64
# Forced_Expiration    470 non-null float64
# Zubrod_scale         470 non-null object
# Pain                 470 non-null object
# Haemoptysis          470 non-null object
# Dyspnoea             470 non-null object
# Cough                470 non-null object
# Weakness             470 non-null object
# Size_of_tumor        470 non-null object
# Diabetes             470 non-null object
# MI_6months           470 non-null object
# PAD                  470 non-null object
# Smoker               470 non-null object
# Asthmatic            470 non-null object
# Age                  470 non-null int64
# Risk_1year           470 non-null object
# dtypes: float64(2), int64(2), object(14)
# memory usage: 66.2+ KB

# %% [markdown]
# ### Checking the data types

# %%
surgery.dtypes
# Out:
# ID                     int64
# Diagnosis             object
# Forced_Capacity      float64
# Forced_Expiration    float64
# Zubrod_scale          object
# Pain                  object
# Haemoptysis           object
# Dyspnoea              object
# Cough                 object
# Weakness              object
# Size_of_tumor         object
# Diabetes              object
# MI_6months            object
# PAD                   object
# Smoker                object
# Asthmatic             object
# Age                    int64
# Risk_1year            object
# dtype: object

# %% [markdown]
# ### Finding number of unique values in each feature

# %%
surgery.select_dtypes('int64').apply(pd.Series.nunique, axis = 0)
# Out:
# ID     470
# Age     45
# dtype: int64

# %%
surgery.select_dtypes('float64').apply(pd.Series.nunique, axis = 0)
# Out:
# Forced_Capacity      134
# Forced_Expiration    136
# dtype: int64

# %%
surgery.select_dtypes('object').apply(pd.Series.nunique, axis = 0)
# Out:
# Diagnosis        7
# Zubrod_scale     3
# Pain             2
# Haemoptysis      2
# Dyspnoea         2
# Cough            2
# Weakness         2
# Size_of_tumor    4
# Diabetes         2
# MI_6months       2
# PAD              2
# Smoker           2
# Asthmatic        2
# Risk_1year       2
# dtype: int64

# %% [markdown]
# ## Visualizations
# #### Categorical Features
#
# Categorical features are present in dataset:
#
# 1. Diagnosis
# 2. Zubrod_scale
# 3. Pain
# 4. Haemoptysis
# 5. Dyspnoea
# 6. Cough
# 7. Weakness
# 8. Size_of_tumor
# 9. Diabetes
# 10. MI_6months
# 11. PAD
# 12. Smoker
# 13. Asthmatic
#
# #### Continuos Features
# 1. Forced_Capacity
# 2. Forced_Expiration
# 3. Age
#
#
# `Target Feature: Risk_1year`

# %% [markdown]
# #### Visualization of Categorical Features

# %%
#List to store column names of categorical features
cat_features=['Diagnosis','Zubrod_scale','Pain','Haemoptysis','Dyspnoea','Cough','Weakness','Size_of_tumor','Diabetes','MI_6months','PAD','Smoker','Asthmatic']
surgery.head()
# Out:
#    ID    Diagnosis  Forced_Capacity  Forced_Expiration    Zubrod_scale   Pain  \
# 0   1  Diagnosis_2             2.88               2.16  Zubrod_scale_1  False
# 1   2  Diagnosis_3             3.40               1.88  Zubrod_scale_0  False
# 2   3  Diagnosis_3             2.76               2.08  Zubrod_scale_1  False
# 3   4  Diagnosis_3             3.68               3.04  Zubrod_scale_0  False
# 4   5  Diagnosis_3             2.44               0.96  Zubrod_scale_2  False
#
#   Haemoptysis Dyspnoea  Cough Weakness Size_of_tumor Diabetes MI_6months  \
# 0       False    False   True     True          OC14    False      False
# 1       False    False  False    False          OC12    False      False
# 2       False    False   True    False          OC11    False      False
# 3       False    False  False    False          OC11    False      False
# 4        True    False   True     True          OC11    False      False
#
#      PAD Smoker Asthmatic  Age Risk_1year
# 0  False   True     False   60      False
# 1  False   True     False   51      False
# 2  False   True     False   59      False
# 3  False  False     False   54      False
# 4  False   True     False   73       True

# %%
plt.figure(figsize=(10,5))
sns.countplot(x='Diagnosis',data=surgery)

# %%
sns.set(style="whitegrid")
for i,cat in enumerate(cat_features[1:]):
    plt.figure(i)
    sns.countplot(x=cat,data=surgery,palette="Set2")

# %% [markdown]
# ### Distribution of Continuous Feature.

# %%
cont_features=['Forced_Capacity','Forced_Expiration','Age']

# %%
sns.set(style="whitegrid")
for i,cont in enumerate(cont_features):
    plt.figure(i)
    sns.distplot(surgery[cont],hist=True,bins=30,color="green")

# %% [markdown]
# ### Relationship between Continuous features

# %%
sns.pairplot(surgery,hue='Risk_1year' )

# %% [markdown]
# #### Box Plot to detect outliers in continuous features

# %%
for i,cont in enumerate(cont_features):
    plt.figure(i)
    ax=sns.boxplot(x=cont,data=surgery)
    ax.plot

# %% [markdown]
# **Above Box plots depict there are outliers in all 3 continuous features. We can use different techniques to handle outliers.**
#
# - Clamp Transformation can be used and check can be placed if it does not impact overall distribution.
# - We can use standard Normalization of data betwen -1 and 1
# - Binning
#
# We can select the best approach after checking the impact on distribution after applying above 3 techniques.

# %% [markdown]
# ## Distrbution of target feature

# %%
sns.countplot(x='Risk_1year',data=surgery,palette="Set3")

# %% [markdown]
# ### There is huge gap in distribution of two levels in target feature. We can use "Over Sampling" Techniques to generate synthetic data for "True" Minority class.

# %% [markdown]
# #### Visualizing continuous and categorical features with target variable

# %%
gs = gridspec.GridSpec(28, 1)
plt.figure(figsize=(6,28*4))
for i, col in enumerate(cont_features):
    ax = plt.subplot(gs[i])
    sns.distplot(surgery[col][surgery.Risk_1year == 'True'], bins=30, color='r')
    sns.distplot(surgery[col][surgery.Risk_1year == 'False'], bins=30, color='g')
    ax.set_xlabel('')
    ax.set_title('feature: ' + str(col))
plt.show()

# %%
#Convert categorical features to numeric
surgery[['Pain','Haemoptysis','Dyspnoea','Cough','Weakness','Diabetes','MI_6months','PAD','Smoker','Asthmatic','Risk_1year']] = \
(surgery[['Pain','Haemoptysis','Dyspnoea','Cough','Weakness','Diabetes','MI_6months','PAD','Smoker','Asthmatic','Risk_1year']] == 'True').astype(int)

# %%
surgery['Diagnosis']= surgery['Diagnosis'].str[-1:].astype(int)
surgery['Zubrod_scale']= surgery['Zubrod_scale'].str[-1:].astype(int)
surgery['Size_of_tumor']= surgery['Size_of_tumor'].str[-1:].astype(int)

# %%
surgery.head()
# Out:
#    ID  Diagnosis  Forced_Capacity  Forced_Expiration  Zubrod_scale  Pain  \
# 0   1          2             2.88               2.16             1     0
# 1   2          3             3.40               1.88             0     0
# 2   3          3             2.76               2.08             1     0
# 3   4          3             3.68               3.04             0     0
# 4   5          3             2.44               0.96             2     0
#
#    Haemoptysis  Dyspnoea  Cough  Weakness  Size_of_tumor  Diabetes  \
# 0            0         0      1         1              4         0
# 1            0         0      0         0              2         0
# 2            0         0      1         0              1         0
# 3            0         0      0         0              1         0
# 4            1         0      1         1              1         0
#
#    MI_6months  PAD  Smoker  Asthmatic  Age  Risk_1year
# 0           0    0       1          0   60           0
# 1           0    0       1          0   51           0
# 2           0    0       1          0   59           0
# 3           0    0       0          0   54           0
# 4           0    0       1          0   73           1

# %%
gs = gridspec.GridSpec(28, 1)
plt.figure(figsize=(6,28*4))
for i, col in enumerate(cat_features):
    ax = plt.subplot(gs[i])
    sns.distplot(surgery[col][surgery.Risk_1year == 1], bins=30, color='r')
    sns.distplot(surgery[col][surgery.Risk_1year == 0], bins=30, color='g')
    ax.set_xlabel('')
    ax.set_title('feature: ' + str(col))
plt.show()

# %%
# Compute the correlation matrix
corr = surgery.corr()

f, ax = plt.subplots(figsize=(11, 5))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(220, 10, as_cmap=True)

sns.heatmap(corr, cmap=cmap, vmax=.3, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})

# %% [markdown]
# ### Random Forest

# %%
surgery.head()
# Out:
#    ID  Diagnosis  Forced_Capacity  Forced_Expiration  Zubrod_scale  Pain  \
# 0   1          2             2.88               2.16             1     0
# 1   2          3             3.40               1.88             0     0
# 2   3          3             2.76               2.08             1     0
# 3   4          3             3.68               3.04             0     0
# 4   5          3             2.44               0.96             2     0
#
#    Haemoptysis  Dyspnoea  Cough  Weakness  Size_of_tumor  Diabetes  \
# 0            0         0      1         1              4         0
# 1            0         0      0         0              2         0
# 2            0         0      1         0              1         0
# 3            0         0      0         0              1         0
# 4            1         0      1         1              1         0
#
#    MI_6months  PAD  Smoker  Asthmatic  Age  Risk_1year
# 0           0    0       1          0   60           0
# 1           0    0       1          0   51           0
# 2           0    0       1          0   59           0
# 3           0    0       0          0   54           0
# 4           0    0       1          0   73           1

# %%
surgery[['Risk_1year']]
# Out:
#      Risk_1year
# 0             0
# 1             0
# 2             0
# 3             0
# 4             1
# ..          ...
# 465           0
# 466           0
# 467           0
# 468           0
# 469           0
#
# [470 rows x 1 columns]

# %%
from sklearn.model_selection import train_test_split

X=surgery.iloc[:,1:-1]
Y=surgery[['Risk_1year']]

# Split dataset into training set and test set
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.2) # 80% training and 20% test

# %%
from sklearn.ensemble import RandomForestClassifier

model_rnf = RandomForestClassifier(n_estimators=500,random_state=42 )
model_rnf.fit(X_train, y_train)

y_pred_rnf = model_rnf.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix, classification_report
cmf=confusion_matrix(y_test,y_pred_rnf)
cmf
# Out:
# array([[82,  0],
#        [12,  0]], dtype=int64)

# %%
model_rnf.score(X_test,y_test)
# Out:
# 0.8723404255319149

# %%
print(classification_report(y_test, y_pred_rnf))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.87      1.00      0.93        82
#            1       0.00      0.00      0.00        12
#
#     accuracy                           0.87        94
#    macro avg       0.44      0.50      0.47        94
# weighted avg       0.76      0.87      0.81        94

# %% [markdown]
# ### Using feature importance for Random forest

# %%
import pandas as pd
feature_imp = pd.Series(model_rnf.feature_importances_).sort_values(ascending=False)
feature_imp
# Out:
# 2     0.221895
# 1     0.215589
# 15    0.179584
# 9     0.083931
# 0     0.073602
# 3     0.043275
# 8     0.028346
# 5     0.028227
# 7     0.026372
# 10    0.025705
# 13    0.023331
# 6     0.021867
# 4     0.021417
# 12    0.006439
# 11    0.000272
# 14    0.000147
# dtype: float64

# %%
X
# Out:
#      Diagnosis  Forced_Capacity  Forced_Expiration  Zubrod_scale  Pain  \
# 0            2             2.88               2.16             1     0
# 1            3             3.40               1.88             0     0
# 2            3             2.76               2.08             1     0
# 3            3             3.68               3.04             0     0
# 4            3             2.44               0.96             2     0
# ..         ...              ...                ...           ...   ...
# 465          2             3.88               2.12             1     0
# 466          3             3.76               3.12             0     0
# 467          3             3.04               2.08             1     0
# 468          3             1.96               1.68             1     0
# 469          3             4.72               3.56             0     0
#
#      Haemoptysis  Dyspnoea  Cough  Weakness  Size_of_tumor  Diabetes  \
# 0              0         0      1         1              4         0
# 1              0         0      0         0              2         0
# 2              0         0      1         0              1         0
# 3              0         0      0         0              1         0
# 4              1         0      1         1              1         0
# ..           ...       ...    ...       ...            ...       ...
# 465            0         0      1         0              3         0
# 466            0         0      0         0              1         0
# 467            0         0      1         0              3         0
# 468            0         0      1         1              2         0
# 469            0         0      0         0              2         0
#
#      MI_6months  PAD  Smoker  Asthmatic  Age
# 0             0    0       1          0   60
# 1             0    0       1          0   51
# 2             0    0       1          0   59
# 3             0    0       0          0   54
# 4             0    0       1          0   73
# ..          ...  ...     ...        ...  ...
# 465           0    0       1          0   63
# 466           0    0       1          0   61
# 467           0    0       0          0   52
# 468           0    0       1          0   79
# 469           0    0       1          0   51
#
# [470 rows x 16 columns]

# %% [markdown]
# ### This shows features indexed 12,11 and 14 are least important. we can try our model without using these features

# %%
X_new=X[['Diagnosis','Forced_Capacity','Forced_Expiration','Zubrod_scale','Haemoptysis','Dyspnoea','Weakness','Size_of_tumor','Diabetes','Age']]

# %%
X_new
# Out:
#      Diagnosis  Forced_Capacity  Forced_Expiration  Zubrod_scale  Haemoptysis  \
# 0            2             2.88               2.16             1            0
# 1            3             3.40               1.88             0            0
# 2            3             2.76               2.08             1            0
# 3            3             3.68               3.04             0            0
# 4            3             2.44               0.96             2            1
# ..         ...              ...                ...           ...          ...
# 465          2             3.88               2.12             1            0
# 466          3             3.76               3.12             0            0
# 467          3             3.04               2.08             1            0
# 468          3             1.96               1.68             1            0
# 469          3             4.72               3.56             0            0
#
#      Dyspnoea  Weakness  Size_of_tumor  Diabetes  Age
# 0           0         1              4         0   60
# 1           0         0              2         0   51
# 2           0         0              1         0   59
# 3           0         0              1         0   54
# 4           0         1              1         0   73
# ..        ...       ...            ...       ...  ...
# 465         0         0              3         0   63
# 466         0         0              1         0   61
# 467         0         0              3         0   52
# 468         0         1              2         0   79
# 469         0         0              2         0   51
#
# [470 rows x 10 columns]

# %%
# Split dataset into training set and test set
X_train_ft, X_test_ft, y_train_ft, y_test_ft = train_test_split(X_new, Y, test_size=0.2) # 70% training and 30% test

# %%
model_rnf_ft = RandomForestClassifier(n_estimators=500,random_state=42)
model_rnf_ft.fit(X_train_ft, y_train_ft)

y_pred_rnf_ft = model_rnf_ft.predict(X_test_ft)

# %%
from sklearn.metrics import confusion_matrix, classification_report
cmf_ft=confusion_matrix(y_test_ft,y_pred_rnf_ft)
cmf_ft
# Out:
# array([[80,  0],
#        [13,  1]], dtype=int64)

# %%
model_rnf_ft.score(X_test_ft,y_test_ft)
# Out:
# 0.8617021276595744

# %%
print(classification_report(y_test_ft, y_pred_rnf_ft))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.86      1.00      0.92        80
#            1       1.00      0.07      0.13        14
#
#     accuracy                           0.86        94
#    macro avg       0.93      0.54      0.53        94
# weighted avg       0.88      0.86      0.81        94

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import precision_score, recall_score, f1_score, confusion_matrix, accuracy_score,classification_report
from sklearn.model_selection import GridSearchCV, StratifiedKFold, cross_val_score, train_test_split
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn import preprocessing

# %% [markdown]
# #### Data Scaling

# %% [markdown]
# Some columns like Diagnosis,Forced_Capacity,Forced_Expiration etc. are not scaled with remaining columns. Hence, performed min-max normalization on these features.

# %%
surgery['Diagnosis']= preprocessing.MinMaxScaler().fit_transform(surgery[['Diagnosis']])
surgery['Forced_Capacity']= preprocessing.MinMaxScaler().fit_transform(surgery[['Forced_Capacity']])
surgery['Forced_Expiration']= preprocessing.MinMaxScaler().fit_transform(surgery[['Forced_Expiration']])
surgery['Zubrod_scale']= preprocessing.MinMaxScaler().fit_transform(surgery[['Zubrod_scale']])
surgery['Size_of_tumor']= preprocessing.MinMaxScaler().fit_transform(surgery[['Size_of_tumor']])
surgery['Age']= preprocessing.MinMaxScaler().fit_transform(surgery[['Age']])

# %%
X=surgery.iloc[:,1:-1]
X_new=X_new.iloc[:,1:]
Y=surgery[['Risk_1year']]

# %%
knn_params = {"n_neighbors": list(range(2, 6, 1)),"weights":['uniform','distance'],'algorithm': ['auto', 'ball_tree', 'kd_tree', 'brute']}
svc_params = {'C': [0.01, 0.7, 0.9, 1,10,100], 'kernel': ['rbf', 'poly', 'sigmoid', 'linear']}
dec_tree_params = {"criterion": ["gini", "entropy"], "max_depth": list(range(2, 6, 1)), "min_samples_leaf": list(range(5, 8, 1))}
log_reg_params = {"penalty": ['l1', 'l2'], 'C': [0.001, 0.01, 0.1, 1, 10, 100, 1000,10000]}
nb_params= {"var_smoothing" : [0.00001,0.0000001]}
rf_params={"n_estimators": list(range(10,100,10)) ,"criterion": ["gini", "entropy"],"max_depth": list(range(2, 6, 1)), "min_samples_leaf": list(range(5, 8, 1))}


classifiers = {
    
    "KNearest": (KNeighborsClassifier(), knn_params),
    "Support Vector Classifier": (SVC(), svc_params),
    "DecisionTreeClassifier": (DecisionTreeClassifier(), dec_tree_params),
    "Naive Bayes": (GaussianNB(), nb_params),
    "Random forests": (RandomForestClassifier(),rf_params),
    "LogisiticRegression": (LogisticRegression(), log_reg_params)
}

def get_best_fit(model, params, X, Y):
    grid = GridSearchCV(estimator=model, param_grid=params)
    grid.fit(X, Y)
    return grid.best_estimator_


def train_all_models(X, Y, folds=5):
    RANDOM_SEED = 0
    for clf_name, (clf, params) in classifiers.items():
        k_fold = StratifiedKFold(n_splits=folds, random_state=RANDOM_SEED, shuffle=True)
        cv_scores = []
        precision_scores = []
        recall_scores = []
        f1_scores = []
        estimators = []
        for train_index, test_index in k_fold.split(X, Y):
            X_train, X_test = pd.DataFrame(data=X, index=train_index), pd.DataFrame(data=X, index=test_index)
            y_train, y_test = pd.DataFrame(data=Y, index=train_index), pd.DataFrame(data=Y, index=test_index)
            model= get_best_fit(clf, params, X_train, y_train)
            estimators.append(model) 
            scores = cross_val_score(model, X_train, y_train.values.ravel(), cv=3, scoring='accuracy')
            cv_scores.append(scores)
            y_pred = model.predict(X_test)
            precision_scores.append(precision_score(y_test, y_pred))
            recall_scores.append(recall_score(y_test, y_pred))
            f1_scores.append(f1_score(y_test, y_pred))
        print('============================= {} ============================='.format(clf_name))
        print('Accuracy score:\n', accuracy_score(y_test, y_pred))
        print()
        print('Confusion matrix:\n', confusion_matrix(y_test, y_pred)) 
        print()
        print('Classification report:\n', classification_report(y_test, y_pred))
        print()
        print('Mean cross validation score: {}'.format(np.array([cv_scores]).mean()))
        print('Mean precision score: {}'.format(np.array([precision_scores]).mean()))
        print('Mean Recall score: {}'.format(np.array([recall_scores]).mean()))
        print('Mean F1 score: {}'.format(np.array([f1_scores]).mean()))
        best_iteration = recall_scores.index(max(recall_scores))
        best_estimator = estimators[best_iteration]
        print('Best estimator: {}'.format(estimators[best_iteration]))

# %%
train_all_models(X, Y)
# Out:
# ============================= KNearest =============================
# Accuracy score:
#  0.851063829787234
#
# Confusion matrix:
#  [[80  0]
#  [14  0]]
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0       0.85      1.00      0.92        80
#            1       0.00      0.00      0.00        14
#
#     accuracy                           0.85        94
#    macro avg       0.43      0.50      0.46        94
# weighted avg       0.72      0.85      0.78        94
#
#
# Mean cross validation score: 0.8446814814814816
# Mean precision score: 0.0
# Mean Recall score: 0.0
# Mean F1 score: 0.0
# Best estimator: KNeighborsClassifier(n_neighbors=4)
# ============================= Support Vector Classifier =============================
# Accuracy score:
#  0.851063829787234
#
# Confusion matrix:
#  [[80  0]
#  [14  0]]
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0       0.85      1.00      0.92        80
#            1       0.00      0.00      0.00        14
#
#     accuracy                           0.85        94
#    macro avg       0.43      0.50      0.46        94
# weighted avg       0.72      0.85      0.78        94
#
#
# Mean cross validation score: 0.8484021164021165
# Mean precision score: 0.0
# Mean Recall score: 0.0
# Mean F1 score: 0.0
# Best estimator: SVC(C=0.7, kernel='poly')
# ============================= DecisionTreeClassifier =============================
# Accuracy score:
#  0.8085106382978723
#
# Confusion matrix:
#  [[75  5]
#  [13  1]]
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0       0.85      0.94      0.89        80
#            1       0.17      0.07      0.10        14
#
#     accuracy                           0.81        94
#    macro avg       0.51      0.50      0.50        94
# weighted avg       0.75      0.81      0.77        94
#
#
# Mean cross validation score: 0.8436063492063491
# Mean precision score: 0.06190476190476191
# Mean Recall score: 0.02857142857142857
# Mean F1 score: 0.039047619047619046
# Best estimator: DecisionTreeClassifier(max_depth=3, min_samples_leaf=6)
# ============================= Naive Bayes =============================
# Accuracy score:
#  0.22340425531914893
#
# Confusion matrix:
#  [[ 7 73]
#  [ 0 14]]
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0       1.00      0.09      0.16        80
#            1       0.16      1.00      0.28        14
#
#     accuracy                           0.22        94
#    macro avg       0.58      0.54      0.22        94
# weighted avg       0.88      0.22      0.18        94
#
#
# Mean cross validation score: 0.25330793650793654
# Mean precision score: 0.16351308611428553
# Mean Recall score: 0.9857142857142858
# Mean F1 score: 0.2800593382419691
# Best estimator: GaussianNB(var_smoothing=1e-05)
# ============================= Random forests =============================
# Accuracy score:
#  0.851063829787234
#
# Confusion matrix:
#  [[80  0]
#  [14  0]]
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0       0.85      1.00      0.92        80
#            1       0.00      0.00      0.00        14
#
#     accuracy                           0.85        94
#    macro avg       0.43      0.50      0.46        94
# weighted avg       0.72      0.85      0.78        94
#
#
# Mean cross validation score: 0.8510687830687832
# Mean precision score: 0.0
# Mean Recall score: 0.0
# Mean F1 score: 0.0
# Best estimator: RandomForestClassifier(max_depth=2, min_samples_leaf=5, n_estimators=10)
# ============================= LogisiticRegression =============================
# Accuracy score:
#  0.851063829787234
#
# Confusion matrix:
#  [[80  0]
#  [14  0]]
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0       0.85      1.00      0.92        80
#            1       0.00      0.00      0.00        14
#
#     accuracy                           0.85        94
#    macro avg       0.43      0.50      0.46        94
# weighted avg       0.72      0.85      0.78        94
#
#
# Mean cross validation score: 0.8510687830687832
# Mean precision score: 0.0
# Mean Recall score: 0.0
# Mean F1 score: 0.0
# Best estimator: LogisticRegression(C=0.001)

# %%
train_all_models(X_new, Y)
# Out:
# ============================= KNearest =============================
# Accuracy score:
#  0.851063829787234
#
# Confusion matrix:
#  [[80  0]
#  [14  0]]
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0       0.85      1.00      0.92        80
#            1       0.00      0.00      0.00        14
#
#     accuracy                           0.85        94
#    macro avg       0.43      0.50      0.46        94
# weighted avg       0.72      0.85      0.78        94
#
#
# Mean cross validation score: 0.84309417989418
# Mean precision score: 0.0
# Mean Recall score: 0.0
# Mean F1 score: 0.0
# Best estimator: KNeighborsClassifier(n_neighbors=2)
# ============================= Support Vector Classifier =============================
# Accuracy score:
#  0.851063829787234
#
# Confusion matrix:
#  [[80  0]
#  [14  0]]
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0       0.85      1.00      0.92        80
#            1       0.00      0.00      0.00        14
#
#     accuracy                           0.85        94
#    macro avg       0.43      0.50      0.46        94
# weighted avg       0.72      0.85      0.78        94
#
#
# Mean cross validation score: 0.8510687830687832
# Mean precision score: 0.0
# Mean Recall score: 0.0
# Mean F1 score: 0.0
# Best estimator: SVC(C=0.01)
# ============================= DecisionTreeClassifier =============================
# Accuracy score:
#  0.851063829787234
#
# Confusion matrix:
#  [[80  0]
#  [14  0]]
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0       0.85      1.00      0.92        80
#            1       0.00      0.00      0.00        14
#
#     accuracy                           0.85        94
#    macro avg       0.43      0.50      0.46        94
# weighted avg       0.72      0.85      0.78        94
#
#
# Mean cross validation score: 0.8473354497354497
# Mean precision score: 0.02857142857142857
# Mean Recall score: 0.014285714285714285
# Mean F1 score: 0.019047619047619046
# Best estimator: DecisionTreeClassifier(criterion='entropy', max_depth=3, min_samples_leaf=6)
# ============================= Naive Bayes =============================
# Accuracy score:
#  0.7659574468085106
#
# Confusion matrix:
#  [[67 13]
#  [ 9  5]]
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0       0.88      0.84      0.86        80
#            1       0.28      0.36      0.31        14
#
#     accuracy                           0.77        94
#    macro avg       0.58      0.60      0.59        94
# weighted avg       0.79      0.77      0.78        94
#
#
# Mean cross validation score: 0.7049566137566139
# Mean precision score: 0.3097938662644545
# Mean Recall score: 0.38571428571428573
# Mean F1 score: 0.3392853170189099
# Best estimator: GaussianNB(var_smoothing=1e-07)
# ============================= Random forests =============================
# Accuracy score:
#  0.851063829787234
#
# Confusion matrix:
#  [[80  0]
#  [14  0]]
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0       0.85      1.00      0.92        80
#            1       0.00      0.00      0.00        14
#
#     accuracy                           0.85        94
#    macro avg       0.43      0.50      0.46        94
# weighted avg       0.72      0.85      0.78        94
#
#
# Mean cross validation score: 0.8505354497354498
# Mean precision score: 0.0
# Mean Recall score: 0.0
# Mean F1 score: 0.0
# Best estimator: RandomForestClassifier(max_depth=2, min_samples_leaf=5, n_estimators=10)
# ============================= LogisiticRegression =============================
# Accuracy score:
#  0.851063829787234
#
# Confusion matrix:
#  [[80  0]
#  [14  0]]
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0       0.85      1.00      0.92        80
#            1       0.00      0.00      0.00        14
#
#     accuracy                           0.85        94
#    macro avg       0.43      0.50      0.46        94
# weighted avg       0.72      0.85      0.78        94
#
#
# Mean cross validation score: 0.8510687830687832
# Mean precision score: 0.0
# Mean Recall score: 0.0
# Mean F1 score: 0.0
# Best estimator: LogisticRegression(C=0.001)
