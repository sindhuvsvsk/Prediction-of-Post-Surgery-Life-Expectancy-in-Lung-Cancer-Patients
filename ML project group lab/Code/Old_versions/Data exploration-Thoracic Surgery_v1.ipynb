# %% [markdown]
# ### Loading the dataset

# %%
import pandas as pd
import numpy as np

# %%
surgery = pd.read_csv("ThoraricSurgery.csv")

# %%
surgery.head()
# Out:
#    id   DGN  PRE4  PRE5  PRE6 PRE7 PRE8 PRE9 PRE10 PRE11 PRE14 PRE17 PRE19  \
# 0   1  DGN2  2.88  2.16  PRZ1    F    F    F     T     T  OC14     F     F
# 1   2  DGN3  3.40  1.88  PRZ0    F    F    F     F     F  OC12     F     F
# 2   3  DGN3  2.76  2.08  PRZ1    F    F    F     T     F  OC11     F     F
# 3   4  DGN3  3.68  3.04  PRZ0    F    F    F     F     F  OC11     F     F
# 4   5  DGN3  2.44  0.96  PRZ2    F    T    F     T     T  OC11     F     F
#
#   PRE25 PRE30 PRE32  AGE Risk1Yr
# 0     F     T     F   60       F
# 1     F     T     F   51       F
# 2     F     T     F   59       F
# 3     F     F     F   54       F
# 4     F     T     F   73       T

# %%
surgery.tail()
# Out:
#       id   DGN  PRE4  PRE5  PRE6 PRE7 PRE8 PRE9 PRE10 PRE11 PRE14 PRE17 PRE19  \
# 465  466  DGN2  3.88  2.12  PRZ1    F    F    F     T     F  OC13     F     F
# 466  467  DGN3  3.76  3.12  PRZ0    F    F    F     F     F  OC11     F     F
# 467  468  DGN3  3.04  2.08  PRZ1    F    F    F     T     F  OC13     F     F
# 468  469  DGN3  1.96  1.68  PRZ1    F    F    F     T     T  OC12     F     F
# 469  470  DGN3  4.72  3.56  PRZ0    F    F    F     F     F  OC12     F     F
#
#     PRE25 PRE30 PRE32  AGE Risk1Yr
# 465     F     T     F   63       F
# 466     F     T     F   61       F
# 467     F     F     F   52       F
# 468     F     T     F   79       F
# 469     F     T     F   51       F

# %% [markdown]
# #### To remove warnings

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Descriptive statistics

# %%
surgery.describe()
# Out:
#                id        PRE4        PRE5         AGE
# count  470.000000  470.000000  470.000000  470.000000
# mean   235.500000    3.281638    4.568702   62.534043
# std    135.821574    0.871395   11.767857    8.706902
# min      1.000000    1.440000    0.960000   21.000000
# 25%    118.250000    2.600000    1.960000   57.000000
# 50%    235.500000    3.160000    2.400000   62.000000
# 75%    352.750000    3.807500    3.080000   69.000000
# max    470.000000    6.300000   86.300000   87.000000

# %% [markdown]
# ### Number of rows and columns

# %%
surgery.shape
# Out:
# (470, 18)

# %% [markdown]
# ### Understanding the data set

# %% [markdown]
# #### Description of the features in the dataset.

# %%
description = pd.read_excel('Thoracic surgery-description.xlsx').dropna()
description.style.set_properties(subset=['Description'])
# Out:
# <style  type="text/css" >
# </style><table id="T_133efa1e_0c06_11eb_be9b_acde48001122" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Attributes</th>        <th class="col_heading level0 col1" >Description</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_133efa1e_0c06_11eb_be9b_acde48001122level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_133efa1e_0c06_11eb_be9b_acde48001122row0_col0" class="data row0 col0" >DGN</td>
#                         <td id="T_133efa1e_0c06_11eb_be9b_acde48001122row0_col1" class="data row0 col1" >Diagnosis - specific combination of ICD-10 codes for primary and secondary as well multiple tumours if any (DGN3,DGN2,DGN4,DGN6,DGN5,DGN8,DGN1)</td>
#             </tr>
#             <tr>
#                         <th id="T_133efa1e_0c06_11eb_be9b_acde48001122level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_133efa1e_0c06_11eb_be9b_acde48001122row1_col0" class="data row1 col0" >PRE4</td>
#                         <td id="T_133efa1e_0c06_11eb_be9b_acde48001122row1_col1" class="data row1 col1" >Forced Vital Capacity - FVC (numeric)</td>
#             </tr>
#             <tr>
#                         <th id="T_133efa1e_0c06_11eb_be9b_acde48001122level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_133efa1e_0c06_11eb_be9b_acde48001122row2_col0" class="data row2 col0" >PRE5</td>
#                         <td id="T_133efa1e_0c06_11eb_be9b_acde48001122row2_col1" class="data row2 col1" >Volume that has been exhaled at the end of the first second of forced expiration - FEV1 (numeric)</td>
#             </tr>
#             <tr>
#                         <th id="T_133efa1e_0c06_11eb_be9b_acde48001122level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_133efa1e_0c06_11eb_be9b_acde48001122row3_col0" class="data row3 col0" >PRE6</td>
#                         <td id="T_133efa1e_0c06_11eb_be9b_acde48001122row3_col1" class="data row3 col1" >Performance status - Zubrod scale (PRZ2,PRZ1,PRZ0)</td>
#             </tr>
#             <tr>
#                         <th id="T_133efa1e_0c06_11eb_be9b_acde48001122level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_133efa1e_0c06_11eb_be9b_acde48001122row4_col0" class="data row4 col0" >PRE7</td>
#                         <td id="T_133efa1e_0c06_11eb_be9b_acde48001122row4_col1" class="data row4 col1" >Pain before surgery (T,F)</td>
#             </tr>
#             <tr>
#                         <th id="T_133efa1e_0c06_11eb_be9b_acde48001122level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_133efa1e_0c06_11eb_be9b_acde48001122row5_col0" class="data row5 col0" >PRE8</td>
#                         <td id="T_133efa1e_0c06_11eb_be9b_acde48001122row5_col1" class="data row5 col1" >Haemoptysis before surgery (T,F)</td>
#             </tr>
#             <tr>
#                         <th id="T_133efa1e_0c06_11eb_be9b_acde48001122level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_133efa1e_0c06_11eb_be9b_acde48001122row6_col0" class="data row6 col0" >PRE9</td>
#                         <td id="T_133efa1e_0c06_11eb_be9b_acde48001122row6_col1" class="data row6 col1" >Dyspnoea before surgery (T,F)</td>
#             </tr>
#             <tr>
#                         <th id="T_133efa1e_0c06_11eb_be9b_acde48001122level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_133efa1e_0c06_11eb_be9b_acde48001122row7_col0" class="data row7 col0" >PRE10</td>
#                         <td id="T_133efa1e_0c06_11eb_be9b_acde48001122row7_col1" class="data row7 col1" >Cough before surgery (T,F)</td>
#             </tr>
#             <tr>
#                         <th id="T_133efa1e_0c06_11eb_be9b_acde48001122level0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_133efa1e_0c06_11eb_be9b_acde48001122row8_col0" class="data row8 col0" >PRE11</td>
#                         <td id="T_133efa1e_0c06_11eb_be9b_acde48001122row8_col1" class="data row8 col1" >Weakness before surgery (T,F)</td>
#             </tr>
#             <tr>
#                         <th id="T_133efa1e_0c06_11eb_be9b_acde48001122level0_row9" class="row_heading level0 row9" >9</th>
#                         <td id="T_133efa1e_0c06_11eb_be9b_acde48001122row9_col0" class="data row9 col0" >PRE14</td>
#                         <td id="T_133efa1e_0c06_11eb_be9b_acde48001122row9_col1" class="data row9 col1" >T in clinical TNM - size of the original tumour, from OC11 (smallest) to OC14 (largest) (OC11,OC14,OC12,OC13)</td>
#             </tr>
#             <tr>
#                         <th id="T_133efa1e_0c06_11eb_be9b_acde48001122level0_row10" class="row_heading level0 row10" >10</th>
#                         <td id="T_133efa1e_0c06_11eb_be9b_acde48001122row10_col0" class="data row10 col0" >PRE17</td>
#                         <td id="T_133efa1e_0c06_11eb_be9b_acde48001122row10_col1" class="data row10 col1" >Type 2 DM - diabetes mellitus (T,F)</td>
#             </tr>
#             <tr>
#                         <th id="T_133efa1e_0c06_11eb_be9b_acde48001122level0_row11" class="row_heading level0 row11" >11</th>
#                         <td id="T_133efa1e_0c06_11eb_be9b_acde48001122row11_col0" class="data row11 col0" >PRE17</td>
#                         <td id="T_133efa1e_0c06_11eb_be9b_acde48001122row11_col1" class="data row11 col1" >MI up to 6 months (T,F)</td>
#             </tr>
#             <tr>
#                         <th id="T_133efa1e_0c06_11eb_be9b_acde48001122level0_row12" class="row_heading level0 row12" >12</th>
#                         <td id="T_133efa1e_0c06_11eb_be9b_acde48001122row12_col0" class="data row12 col0" >PRE19</td>
#                         <td id="T_133efa1e_0c06_11eb_be9b_acde48001122row12_col1" class="data row12 col1" >PAD - Peripheral Arterial Diseases (T,F)</td>
#             </tr>
#             <tr>
#                         <th id="T_133efa1e_0c06_11eb_be9b_acde48001122level0_row13" class="row_heading level0 row13" >13</th>
#                         <td id="T_133efa1e_0c06_11eb_be9b_acde48001122row13_col0" class="data row13 col0" >PRE30</td>
#                         <td id="T_133efa1e_0c06_11eb_be9b_acde48001122row13_col1" class="data row13 col1" >Smoking (T,F)</td>
#             </tr>
#             <tr>
#                         <th id="T_133efa1e_0c06_11eb_be9b_acde48001122level0_row14" class="row_heading level0 row14" >14</th>
#                         <td id="T_133efa1e_0c06_11eb_be9b_acde48001122row14_col0" class="data row14 col0" >PRE32</td>
#                         <td id="T_133efa1e_0c06_11eb_be9b_acde48001122row14_col1" class="data row14 col1" >Asthma (T,F)</td>
#             </tr>
#             <tr>
#                         <th id="T_133efa1e_0c06_11eb_be9b_acde48001122level0_row15" class="row_heading level0 row15" >15</th>
#                         <td id="T_133efa1e_0c06_11eb_be9b_acde48001122row15_col0" class="data row15 col0" >AGE</td>
#                         <td id="T_133efa1e_0c06_11eb_be9b_acde48001122row15_col1" class="data row15 col1" >Age at the time of surgery (numeric)</td>
#             </tr>
#             <tr>
#                         <th id="T_133efa1e_0c06_11eb_be9b_acde48001122level0_row16" class="row_heading level0 row16" >16</th>
#                         <td id="T_133efa1e_0c06_11eb_be9b_acde48001122row16_col0" class="data row16 col0" >Risk1Y</td>
#                         <td id="T_133efa1e_0c06_11eb_be9b_acde48001122row16_col1" class="data row16 col1" >1 year survival period - (T)rue value if died (T,F)</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# ### Renaming the attributes of the dataset

# %%
col = ['ID','Diagnosis','Forced_Capacity','Forced_Expiration','Zubrod_scale','Pain','Haemoptysis','Dyspnoea',
       'Cough','Weakness','Size_of_tumor','Diabetes','MI_6months','PAD','Smoker','Asthmatic','Age','Risk_1year']
surgery.columns = col

# %%
surgery.head()
# Out:
#    ID Diagnosis  Forced_Capacity  Forced_Expiration Zubrod_scale Pain  \
# 0   1      DGN2             2.88               2.16         PRZ1    F
# 1   2      DGN3             3.40               1.88         PRZ0    F
# 2   3      DGN3             2.76               2.08         PRZ1    F
# 3   4      DGN3             3.68               3.04         PRZ0    F
# 4   5      DGN3             2.44               0.96         PRZ2    F
#
#   Haemoptysis Dyspnoea Cough Weakness Size_of_tumor Diabetes MI_6months PAD  \
# 0           F        F     T        T          OC14        F          F   F
# 1           F        F     F        F          OC12        F          F   F
# 2           F        F     T        F          OC11        F          F   F
# 3           F        F     F        F          OC11        F          F   F
# 4           T        F     T        T          OC11        F          F   F
#
#   Smoker Asthmatic  Age Risk_1year
# 0      T         F   60          F
# 1      T         F   51          F
# 2      T         F   59          F
# 3      F         F   54          F
# 4      T         F   73          T

# %% [markdown]
# ### Missing values

# %% [markdown]
# #### Checking the number of null values and data type of the variables present in the data set

# %%
surgery.isna().sum()
# Out:
# ID                   0
# Diagnosis            0
# Forced_Capacity      0
# Forced_Expiration    0
# Zubrod_scale         0
# Pain                 0
# Haemoptysis          0
# Dyspnoea             0
# Cough                0
# Weakness             0
# Size_of_tumor        0
# Diabetes             0
# MI_6months           0
# PAD                  0
# Smoker               0
# Asthmatic            0
# Age                  0
# Risk_1year           0
# dtype: int64

# %% [markdown]
# #### Calculating the number of missing vallues in each feature of the dataset

# %%
missing = surgery.isnull().sum()
missing_perc = (missing/len(surgery))*100
miss_val_table = pd.concat([missing, missing_perc], axis=1)
miss_val_table_rename_col = miss_val_table.rename(columns = {0 : 'Missing Values', 1 : '% of MissingValues'})
miss_val_table_rename_col = miss_val_table_rename_col[miss_val_table_rename_col.iloc[:,1] != 0].sort_values('% of MissingValues', ascending=False).round(1)
print("Thoracic Surgery dataset has " + str(surgery.shape[1]) + " columns.\nThere are "+ str(miss_val_table_rename_col.shape[0]) + " columns that have missing values.")
# Out:
# Thoracic Surgery dataset has 18 columns.
# There are 0 columns that have missing values.

# %% [markdown]
# #### Changing the values of the categorical variables, to improve the interpretation

# %%
surgery['Diagnosis'][surgery['Diagnosis'] == 'DGN1'] = 'Diagnosis_1'
surgery['Diagnosis'][surgery['Diagnosis'] == 'DGN2'] = 'Diagnosis_2'
surgery['Diagnosis'][surgery['Diagnosis'] == 'DGN3'] = 'Diagnosis_3'
surgery['Diagnosis'][surgery['Diagnosis'] == 'DGN4'] = 'Diagnosis_4'
surgery['Diagnosis'][surgery['Diagnosis'] == 'DGN5'] = 'Diagnosis_5'
surgery['Diagnosis'][surgery['Diagnosis'] == 'DGN6'] = 'Diagnosis_6'
surgery['Diagnosis'][surgery['Diagnosis'] == 'DGN8'] = 'Diagnosis_8'

surgery['Zubrod_scale'][surgery['Zubrod_scale'] == 'PRZ0'] = 'Zubrod_scale_0'
surgery['Zubrod_scale'][surgery['Zubrod_scale'] == 'PRZ1'] = 'Zubrod_scale_1'
surgery['Zubrod_scale'][surgery['Zubrod_scale'] == 'PRZ2'] = 'Zubrod_scale_2'

surgery['Pain'][surgery['Pain'] == 'F'] = 'False'
surgery['Pain'][surgery['Pain'] == 'T'] = 'True'

surgery['Haemoptysis'][surgery['Haemoptysis'] == 'F'] = 'False'
surgery['Haemoptysis'][surgery['Haemoptysis'] == 'T'] = 'True'

surgery['Dyspnoea'][surgery['Dyspnoea'] == 'F'] = 'False'
surgery['Dyspnoea'][surgery['Dyspnoea'] == 'T'] = 'True'

surgery['Cough'][surgery['Cough'] == 'F'] = 'False'
surgery['Cough'][surgery['Cough'] == 'T'] = 'True'

surgery['Weakness'][surgery['Weakness'] == 'F'] = 'False'
surgery['Weakness'][surgery['Weakness'] == 'T'] = 'True'

surgery['Diabetes'][surgery['Diabetes'] == 'F'] = 'False'
surgery['Diabetes'][surgery['Diabetes'] == 'T'] = 'True'

surgery['MI_6months'][surgery['MI_6months'] == 'F'] = 'False'
surgery['MI_6months'][surgery['MI_6months'] == 'T'] = 'True'


surgery['PAD'][surgery['PAD'] == 'F'] = 'False'
surgery['PAD'][surgery['PAD'] == 'T'] = 'True'


surgery['Smoker'][surgery['Smoker'] == 'F'] = 'False'
surgery['Smoker'][surgery['Smoker'] == 'T'] = 'True'

surgery['Asthmatic'][surgery['Asthmatic'] == 'F'] = 'False'
surgery['Asthmatic'][surgery['Asthmatic'] == 'T'] = 'True'

surgery['Risk_1year'][surgery['Risk_1year'] == 'F'] = 'False'
surgery['Risk_1year'][surgery['Risk_1year'] == 'T'] = 'True'

# %%
surgery.head()
# Out:
#    ID    Diagnosis  Forced_Capacity  Forced_Expiration    Zubrod_scale   Pain  \
# 0   1  Diagnosis_2             2.88               2.16  Zubrod_scale_1  False
# 1   2  Diagnosis_3             3.40               1.88  Zubrod_scale_0  False
# 2   3  Diagnosis_3             2.76               2.08  Zubrod_scale_1  False
# 3   4  Diagnosis_3             3.68               3.04  Zubrod_scale_0  False
# 4   5  Diagnosis_3             2.44               0.96  Zubrod_scale_2  False
#
#   Haemoptysis Dyspnoea  Cough Weakness Size_of_tumor Diabetes MI_6months  \
# 0       False    False   True     True          OC14    False      False
# 1       False    False  False    False          OC12    False      False
# 2       False    False   True    False          OC11    False      False
# 3       False    False  False    False          OC11    False      False
# 4        True    False   True     True          OC11    False      False
#
#      PAD Smoker Asthmatic  Age Risk_1year
# 0  False   True     False   60      False
# 1  False   True     False   51      False
# 2  False   True     False   59      False
# 3  False  False     False   54      False
# 4  False   True     False   73       True

# %% [markdown]
# ### Displaying  data present in the csv file

# %%
surgery.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 470 entries, 0 to 469
# Data columns (total 18 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   ID                 470 non-null    int64
#  1   Diagnosis          470 non-null    object
#  2   Forced_Capacity    470 non-null    float64
#  3   Forced_Expiration  470 non-null    float64
#  4   Zubrod_scale       470 non-null    object
#  5   Pain               470 non-null    object
#  6   Haemoptysis        470 non-null    object
#  7   Dyspnoea           470 non-null    object
#  8   Cough              470 non-null    object
#  9   Weakness           470 non-null    object
#  10  Size_of_tumor      470 non-null    object
#  11  Diabetes           470 non-null    object
#  12  MI_6months         470 non-null    object
#  13  PAD                470 non-null    object
#  14  Smoker             470 non-null    object
#  15  Asthmatic          470 non-null    object
#  16  Age                470 non-null    int64
#  17  Risk_1year         470 non-null    object
# dtypes: float64(2), int64(2), object(14)
# memory usage: 66.2+ KB

# %% [markdown]
# ### Checking the data types

# %%
surgery.dtypes
# Out:
# ID                     int64
# Diagnosis             object
# Forced_Capacity      float64
# Forced_Expiration    float64
# Zubrod_scale          object
# Pain                  object
# Haemoptysis           object
# Dyspnoea              object
# Cough                 object
# Weakness              object
# Size_of_tumor         object
# Diabetes              object
# MI_6months            object
# PAD                   object
# Smoker                object
# Asthmatic             object
# Age                    int64
# Risk_1year            object
# dtype: object

# %% [markdown]
# ### Finding number of unique values in each feature

# %%
surgery.select_dtypes('int64').apply(pd.Series.nunique, axis = 0)
# Out:
# ID     470
# Age     45
# dtype: int64

# %%
surgery.select_dtypes('float64').apply(pd.Series.nunique, axis = 0)
# Out:
# Forced_Capacity      134
# Forced_Expiration    136
# dtype: int64

# %%
surgery.select_dtypes('object').apply(pd.Series.nunique, axis = 0)
# Out:
# Diagnosis        7
# Zubrod_scale     3
# Pain             2
# Haemoptysis      2
# Dyspnoea         2
# Cough            2
# Weakness         2
# Size_of_tumor    4
# Diabetes         2
# MI_6months       2
# PAD              2
# Smoker           2
# Asthmatic        2
# Risk_1year       2
# dtype: int64

# %% [markdown]
# ### Further exploration of the dataset

# %%
surgery_hist = surgery.hist(bins=10, figsize=(20, 20))
